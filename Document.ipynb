# %%
p0 = 0+0+0+10+4+4+6+4+0+2+0+0+0+2+0+0
wp0 = 435 - (10/32)*22 + (4/32)*18 + (4/32)*14 + (6/32)*8 + (4/32)*4 + (2/32)*2 + (2/32)*0
ep0 = (10/32)*4 + (4/32)*1 + (4/32)*1 + (6/32)*2 + (4/32)*1 + (2/32)*0 + (2/32)*0

p1 = 0+0+2+8+4+4+8+4+0+0+4+0+2+0+2
wp1 = 435 - (
    (2/38)*36 + (8/38)*28 + (4/38)*24 + (4/38)*20 + (8/38)*12 + (4/38)*8 + (4/38)*4 + (2/38)*2 + (2/38)*0
    + (435 - wp0)
    + ep0
    )
ep1 = (2/38)*0 + (8/38)*3 + (4/38)*1 + (4/38)*1 + (8/38)*3 + (4/38)*1 + (4/38)*1 + (2/38)*0 + (2/38)*0

p2 = 8+8+8+4+0+6+4+0+0+4+2+2+0+4+0+0
wp2 = 435 - (
    (8/50)*42 + (8/50)*34 + (8/50)*26 + (4/50)*22 + (6/50)*16 + (4/50)*12 + (4/50)*8 + (2/50)*6 + (2/50)*4 + (4/50)*0 
    + (435 -wp1) + (435 - wp0)
    + ep0 + ep1
    )
ep2 = (8/50)*3 + (8/50)*3 + (8/50)*3 + (4/50)*1 + (6/50)*2 + (4/50)*1 + (4/50)*1 + (2/50)*0 + (2/50)*0 + (4/50)*1

p3 = 4+4+4+4+2+8+4+0+2+6+4+0+4+2+0+0+0
wp3 = 435 - (
    (4/48)*44 + (4/48)*40 + (4/48)*36 + (4/48)*32 + (2/48)*30 + (8/48)*22 + (4/48)*18 + (2/48)*16 + (6/48)*10 + (4/48)*6 + (4/48)*2 + (2/48)*0 
    + (435 - wp2) + (435 - wp1) + (435 - wp0)
    + ep0 + ep1 + ep2
    )
ep3 = (4/48)*1 + (4/48)*1 + (4/48)*1 + (4/48)*1 + (2/48)*0 + (8/48)*3 + (4/48)*1 + (2/48)*0 + (6/48)*2 + (4/48)*1 + (4/48)*1 + (2/48)*0

p4 = 4+0+10+8+4+4+4+2+0+4+4+4+2+0+0+0+0
wp4 = 435 - (
    (4/50)*46 + (10/50)*36 + (8/50)*28 + (4/50)*24 + (4/50)*20 + (4/50)*16 + (2/50)*14 + (4/50)*10 + (4/50)*6 + (4/50)*2 + (2/50)*0
    + (435 - wp3) + (435 - wp2) + (435 - wp1) + (435 - wp0)
    + ep0 + ep1 + ep2 + ep3
    )
ep4 = (4/50)*1 + (10/50)*4 + (8/50)*3 + (4/50)*1 + (4/50)*1 + (4/50)*1 + (2/50)*0 + (4/50)*1 + (4/50)*1 + (4/50)*1 + (2/50)*0 


p5 = 2+2+8+4+4+4+4+0+4+4+4+2+4+0+0+0+0
wp5 = 435 - (
    (2/46)*44 + (2/46)*42 + (8/46)*34 + (4/46)*30 + (4/46)*26 + (4/46)*22 + (4/46)*18 + (4/46)*14 + (4/46)*10 + (4/46)*6 + (2/46)*4 + (4/46)*0
    + (435 - wp4) + (435 - wp3) + (435 - wp2) + (435 - wp1) + (435 - wp0)
    + ep0 + ep1 + ep2 + ep3 + ep4
    )
ep5 = (2/46)*1 + (2/46)*1 + (8/46)*3 + (4/46)*1 + (4/46)*1 + (4/46)*1 + (4/46)*1 + (4/46)*1 + (4/46)*1 + (4/46)*1 + (2/46)*0 + (4/46)*1 







p6 = 8+8+4+0+10+4+0+4+6+4+0+4+0+0+0+0+0
wp6 = 435 - (
    (8/48)*44 + (8/48)*40 + (4/48)*36 + (10/48)*28 + (4/48)*24 + (4/48)*20 + (4/48)*16 + (6/48)*12 + (4/48)*8 + (4/48)*4 + (2/48)*2 + (4/48)*0
    + (435 - wp5) + (435 - wp4) + (435 - wp3) + (435 - wp2) + (435 - wp1) + (435 - wp0)
    + ep0 + ep1 + ep2 + ep3 + ep4 + ep5
    )
ep6 = (8/48)*3 + (8/48)*3 + (4/48)*1 + (10/48)*4 + (4/48)*1 + (4/48)*1 + (4/48)*1 + (6/48)*2 + (4/48)*1 + (4/48)*1 + (2/48)*0 + (4/48)*1

p7 = 4+4+4+2+8+4+2+6+8+0+0+4+0+0+0+0+0

p8 = 6+4+4+4+4+2+4+4+4+0+2+0+0+0+0+0+0

p_dg9 = 4
p_tg9 = 2
p_dg = 8
p_tg = 8
p_dw = 4
p_tw = 4
p_z5_st = 15
p_zz = 1

# %%
p8
# Out:
# 38
